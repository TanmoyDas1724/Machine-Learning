# %%
pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-1.0.0-py3-none-any.whl.metadata (40 kB)
# Collecting kagglesdk<1.0,>=0.1.14 (from kagglehub)
#   Downloading kagglesdk-0.1.19-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in c:\users\tanmo\appdata\local\programs\python\python313\lib\site-packages (from kagglehub) (24.2)
# Requirement already satisfied: pyyaml in c:\users\tanmo\appdata\local\programs\python\python313\lib\site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in c:\users\tanmo\appdata\local\programs\python\python313\lib\site-packages (from kagglehub) (2.32.3)
# Collecting tqdm (from kagglehub)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: protobuf in c:\users\tanmo\appdata\local\programs\python\python313\lib\site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (6.32.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tanmo\appdata\local\programs\python\python313\lib\site-packages (from requests->kagglehub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tanmo\appdata\local\programs\python\python313\lib\site-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tanmo\appdata\local\programs\python\python313\lib\site-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tanmo\appdata\local\programs\python\python313\lib\site-packages (from requests->kagglehub) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\tanmo\appdata\local\programs\python\python313\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-1.0.0-py3-none-any.whl (70 kB)
# Downloading kagglesdk-0.1.19-py3-none-any.whl (208 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, kagglesdk, kagglehub
# Successfully installed kagglehub-1.0.0 kagglesdk-0.1.19 tqdm-4.67.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import kagglehub

# Download latest version
path = kagglehub.competition_download('house-prices-advanced-regression-techniques')

print("Path to competition files:", path)
# Out:
# ---------------------------------------------------------------------------
# UnauthenticatedError                      Traceback (most recent call last)
# Cell In[3], line 4
#       1 import kagglehub
#       3 # Download latest version
# ----> 4 path = kagglehub.competition_download('house-prices-advanced-regression-techniques')
#       6 print("Path to competition files:", path)
#
# File c:\Users\tanmo\AppData\Local\Programs\Python\Python313\Lib\site-packages\kagglehub\competition.py:30, in competition_download(handle, path, force_download, output_dir)
#      28 h = parse_competition_handle(handle)
#      29 logger.info(f"Downloading competition: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 30 path, _ = registry.competition_resolver(
#      31     h,
#      32     path,
#      33     force_download=force_download,
#      34     output_dir=output_dir,
#      35 )
#      36 return path
#
# File c:\Users\tanmo\AppData\Local\Programs\Python\Python313\Lib\site-packages\kagglehub\registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File c:\Users\tanmo\AppData\Local\Programs\Python\Python313\Lib\site-packages\kagglehub\resolver.py:35, in Resolver.__call__(self, handle, path, force_download, output_dir)
#      15 def __call__(
#      16     self,
#      17     handle: T,
#    (...)
#      21     output_dir: str | None = None,
#      22 ) -> tuple[str, int | None]:
#      23     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      24
#      25     Args:
#    (...)
#      33         Some cases where version number might be missing: Competition datasource, API-based models.
#      34     """
# ---> 35     path, version = self._resolve(
#      36         handle,
#      37         path,
#      38         force_download=force_download,
#      39         output_dir=output_dir,
#      40     )
#      42     # Note handles are immutable, so _resolve() could not have altered our reference
#      43     register_datasource_access(handle, version)
#
# File c:\Users\tanmo\AppData\Local\Programs\Python\Python313\Lib\site-packages\kagglehub\http_resolver.py:55, in CompetitionHttpResolver._resolve(self, h, path, force_download, output_dir)
#      53     if cached_path:
#      54         return cached_path, None
# ---> 55     raise UnauthenticatedError()
#      57 out_path = cache.get_path(h, path)
#      59 if output_dir:
#
# UnauthenticatedError: User is not authenticated
